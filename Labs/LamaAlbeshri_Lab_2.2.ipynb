# %% [markdown]
# # Python_Lab_2.2

# %% [markdown]
# ### Task 11. Write a program that prompts the user to enter two numbers and prints their division. Handle cases where the user enters non-numeric values or attempts to divide by zero using a try-except block.

# %%
def divide_numbers():
    while True:
        num_1 = input("Enter first number: ")
        num_2 = input("Enter second number: ")

        try:
            num_1 =float(num_1)
            num_2 = float(num_2)

            result = num_1 / num_2
            print(f"The result of {num_1} divided by {num_2} is {result}")
            break  
        except ValueError:
            print("Invalid input, enter numeric values.")
        except ZeroDivisionError:
            print("Error: Division by zero is not allowed. Please enter a non-zero")

divide_numbers()
# Out:
# The result of 8.0 divided by 9.0 is 0.8888888888888888

# %% [markdown]
# ### Task 2
# - Use "Random" library to do the following:
#     1. Create a list of random numbers using list comprehension.
#     2. Create a list of squares of the even numbers from random numbers using list comprehension.
#     3. Create a list of tuples (number, square) for random numbers using list comprehension.

# %%
#  1.
import random

random_number = [random.randint(1, 100) for _ in range(10)]
print(random_number)
 #2.
squares_even = [num**2 for num in random_number if num % 2 == 0]
print("squares_even",squares_even)
# 3. 
tuple_square = [(num, num**2) for num in random_number]
print("tuple_square",tuple_square)
# Out:
# [67, 96, 50, 39, 75, 2, 62, 32, 82, 67]
# squares_even [9216, 2500, 4, 3844, 1024, 6724]
# tuple_square [(67, 4489), (96, 9216), (50, 2500), (39, 1521), (75, 5625), (2, 4), (62, 3844), (32, 1024), (82, 6724), (67, 4489)]

# %% [markdown]
# ### Task 3
# - Create a dictionary where the keys are numbers from 1 to 5 and the values are list of their squares and cubes.
#
#   - **hint**: use dictionary of list comprehension.
#
# - Create a dictionary from two lists (one with keys and one with values) using dictionary comprehension.

# %%
squares_and_cubes = { x: [x**2, x**3] for x in range(1, 6)}
print(squares_and_cubes)

#Create a dictionary from two lists 
name=['amal', 'Lama ', 'Ahmad']
score = [99,89,99]

dic_comp = {name[i]:score[i] for i in range(len(name))}
print(dic_comp)
# Out:
# {1: [1, 1], 2: [4, 8], 3: [9, 27], 4: [16, 64], 5: [25, 125]}
# {'amal': 99, 'Lama ': 89, 'Ahmad': 99}

# %% [markdown]
# ### Task 4
# - Given a dictionary where keys are student names and values are lists of their scores, write a function that updates the scores of students who have achieved a perfect score (100) by adding a bonus of 5 points to each score. Use dictionary comprehension to achieve this.
#
#     - Implement the function add_bonus_to_perfect_scores(student_scores) that adds a bonus of 5 points to each score of students who have achieved a perfect score (100).

# %%
dic_student = {
    "Lama": [98, 80],
    "Ahmad": [90, 100]
}

def add_bonus_to_perfect_score(student_scores):
    updated_scores = {student: [score + 5 if score == 100 else score for score in scores]
    for student, scores in student_scores.items()}
    return updated_scores

dic_result = add_bonus_to_perfect_score(dic_student)
print(dic_result)
# Out:
# {'Lama': [98, 80], 'Ahmad': [90, 105]}
