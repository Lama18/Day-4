# %% [markdown]
# # Python_Lab_2.1

# %% [markdown]
# ### Task 1
# 1. Write a function named is_prime that takes a number as a parameter and returns True if the number is prime and False otherwise. Print whether the number 29 is prime.

# %%
num =10
def is_prime(number):
  if number > 1:
    for i in range (2,int(number//2)+1):
        if number %i==0:
            return False
    return True

result=is_prime(num)
print (f" number {num} is prime? {result}")
# Out:
#  number 10 is prime? False

# %% [markdown]
# ### Task 2
# 1. Create a list of 10 numbers and sort them in descending order using the sort() function.
# 2. Use the len() function to print the length of the sorted list.
# 3. Use the zip() function to combine three lists (names, ages, and cities) into a list of tuples.
# 4. Use the range() function to create a list of even numbers from 2 to 20 and print the list.

# %%
#reverse sort 
num=[11,2,35,4,5,66,7,80,9,10]
num.sort(reverse=True)
print(num)

#len function
print (f"length of list is : {len(num)}")

#range function 
even_num= range(2,20,2)
print (f"list of even numbers is :{list(even_num)}")
# Out:
# [80, 66, 35, 11, 10, 9, 7, 5, 4, 2]
# length of list is : 10
# list of even numbers is :[2, 4, 6, 8, 10, 12, 14, 16, 18]

# %% [markdown]
# ### Task 3
# Build a phone book program that receives the phone number, and returns the name of the owner.
# You can follow the table below:
#
# | Name     | Number     |
# | -------- | ---------- |
# | Amal     | 1111111111 |
# | Mohammed | 2222222222 |
# | Khadijah | 3333333333 |
# | Abdullah | 4444444444 |
# | Rawan    | 5555555555 |
# | Faisal   | 6666666666 |
# | Layla    | 7777777777 |
#
# - If the number exists, print the owner. Otherwise, print "Sorry, the number is not found".
# - If the number is less or more than 10 numbers, print "This is invalid number".
# - If the number contains letters or symbols, print "This is invalid number".

# %%
#dictionary:
dic_phone={
    "Amal":1111111111,
    "Mohammed":2222222222,
    "Khadijah":3333333333,
    "Abdullah":4444444444,
    "Rawan":5555555555,
    "Faisal":6666666666,
    "Layla":7777777777
}

def owner_phone(phone_number):

    if len(phone_number) != 10 or not phone_number.isdigit():
        return "This is invalid number."
    
    # Check if the number exists in the phone book
    for name,num in dic_phone.items():
        if dic_phone.values() == phone_number:
            return f"The owner of {phone_number} is {dic_phone.keys()}."
        else:
            return "Sorry, the number is not found."

# Ask user for input
ask_user = input("Enter phone number: ")
owner = owner_phone(ask_user)
print(owner)
# Out:
# This is invalid number.

# %% [markdown]
# ### Task 4
# - Given the following list : [5, 4, 17, 19, 30, 2, 7, 10, 45]
#     1. Use a lambda function to filter out only the odd numbers.
#     2. Print the new list of odd numbers.

# %%
#lambda function 
task_list=[5,4,17,19,30,2,7,10,45]
odd_filter=filter(lambda itme :itme %2!=0 ,task_list)
print (list(odd_filter))
# Out:
# [5, 17, 19, 7, 45]
